# %%
import pandas as pd

# %%
data = pd.read_csv(r"sentimentdataset.csv")
data
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# 728  Attending a surprise birthday party organized ...       Happy
# 729  Successfully fundraising for a school charity ...       Happy
# 730  Participating in a multicultural festival, cel...       Happy
# 731  Organizing a virtual talent show during challe...       Happy
#
#                Timestamp                                   User     Platform  \
# 0    2023-01-15 12:30:00                          User123          Twitter
# 1    2023-01-15 08:45:00                          CommuterX        Twitter
# 2    2023-01-15 15:45:00                          FitnessFan      Instagram
# 3    2023-01-15 18:20:00                          AdventureX       Facebook
# 4    2023-01-15 19:55:00                          ChefCook        Instagram
# ..                   ...                                    ...          ...
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# 731  2020-11-15 15:15:00    VirtualTalentShowSuccessHighSchool    Instagram
#
#                                           Hashtags  Retweets  Likes  \
# 0        #Nature #Park                                  15.0   30.0
# 1        #Traffic #Morning                               5.0   10.0
# 2        #Fitness #Workout                              20.0   40.0
# 3        #Travel #Adventure                              8.0   15.0
# 4        #Cooking #Food                                 12.0   25.0
# ..                                             ...       ...    ...
# 727         #ScienceFairWinner #HighSchoolScience       20.0   39.0
# 728    #SurpriseCelebration #HighSchoolFriendship       25.0   48.0
# 729      #CommunityGiving #HighSchoolPhilanthropy       22.0   42.0
# 730         #CulturalCelebration #HighSchoolUnity       21.0   43.0
# 731   #VirtualEntertainment #HighSchoolPositivity       24.0   47.0
#
#           Country  Year  Month  Day  Hour
# 0       USA        2023      1   15    12
# 1       Canada     2023      1   15     8
# 2     USA          2023      1   15    15
# 3       UK         2023      1   15    18
# 4      Australia   2023      1   15    19
# ..            ...   ...    ...  ...   ...
# 727            UK  2017      8   18    18
# 728           USA  2018      6   22    14
# 729        Canada  2019      4    5    17
# 730            UK  2020      2   29    20
# 731           USA  2020     11   15    15
#
# [732 rows x 15 columns]

# %%
df = data.copy()

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# 2   #Fitness #Workout                              20.0   40.0   USA
# 3   #Travel #Adventure                              8.0   15.0     UK
# 4   #Cooking #Food                                 12.0   25.0    Australia
#
#    Year  Month  Day  Hour
# 0  2023      1   15    12
# 1  2023      1   15     8
# 2  2023      1   15    15
# 3  2023      1   15    18
# 4  2023      1   15    19

# %% [markdown]
# # Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# max     12.000000   31.000000   23.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
df=df.drop(columns=['Unnamed: 0.1','Unnamed: 0'], axis=1)
df.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# 2   #Fitness #Workout                              20.0   40.0   USA
# 3   #Travel #Adventure                              8.0   15.0     UK
# 4   #Cooking #Food                                 12.0   25.0    Australia
#
#    Year  Month  Day  Hour
# 0  2023      1   15    12
# 1  2023      1   15     8
# 2  2023      1   15    15
# 3  2023      1   15    18
# 4  2023      1   15    19

# %%
df.duplicated().sum()
# Out:
# np.int64(20)

# %%
# Removing the duplicates
df.drop_duplicates(inplace=True)

# %%
# Changing the Timestamp to datetime format
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# Getting the day of the week and Month
df['Day_of_week'] = df['Timestamp'].dt.day_name()
df['Month'] = df['Timestamp'].dt.month_name()

# %%
df['Country'].unique()
# Out:
# array([' USA      ', ' Canada   ', ' USA        ', ' UK       ',
#        ' Australia ', ' India    ', ' USA    ', 'USA', ' Canada    ',
#        ' USA       ', ' USA ', ' Canada  ', ' UK ', ' India     ',
#        ' Canada ', ' UK        ', ' India ', ' UK   ', ' UK         ',
#        ' USA     ', ' Canada     ', ' USA          ', ' India      ',
#        ' Australia  ', ' UK           ', ' Canada       ',
#        ' Australia   ', ' Australia    ', ' UK            ', ' USA   ',
#        ' India       ', ' UK          ', ' USA  ', ' UK      ',
#        ' Canada      ', ' India   ', ' Canada          ',
#        ' India        ', ' Australia     ', ' Canada        ',
#        ' India         ', ' USA           ', ' USA               ',
#        ' Canada            ', ' UK                ',
#        ' India              ', ' Australia          ',
#        ' France            ', ' Brazil            ',
#        ' Japan             ', ' Greece            ',
#        ' India             ', ' Brazil           ', ' France           ',
#        ' Japan            ', ' Canada           ', ' Australia         ',
#        ' UK               ', ' USA             ', ' Greece           ',
#        ' Germany         ', ' Sweden          ', ' Italy           ',
#        ' Netherlands     ', ' South Africa    ', ' Spain           ',
#        ' Portugal        ', ' Switzerland     ', ' Austria         ',
#        ' Belgium         ', ' Denmark         ', ' Czech Republic  ',
#        ' Canada         ', ' France          ', ' UK              ',
#        ' India          ', ' Australia      ', ' Japan           ',
#        ' Brazil          ', ' Germany       ', ' Australia        ',
#        ' France         ', ' Italy         ', ' Japan       ',
#        ' Spain        ', ' Netherlands  ', ' South Africa ',
#        ' Germany     ', ' USA         ', ' France    ', ' Brazil     ',
#        ' Germany ', ' Brazil ', ' France ', ' Italy ', ' Japan ',
#        ' Spain ', ' Netherlands ', ' Greece ', ' Jordan ', ' Peru ',
#        ' Maldives ', ' China ', ' Cambodia ', ' Switzerland ', ' Norway ',
#        ' Colombia ', ' Ireland ', ' Jamaica ', ' Kenya ', ' Scotland ',
#        ' Thailand ', ' USA', ' Canada', ' UK'], dtype=object)

# %%
df['Country'].value_counts()
# Out:
# Country
# USA           59
# USA           51
# UK            49
# Canada        44
# Australia     36
#               ..
# Ireland        1
# Scotland       1
# Kenya          1
# Jamaica        1
# Thailand       1
# Name: count, Length: 115, dtype: int64

# %% [markdown]
# ### USA counted 2 times , so need to trim the data to get the Accuracy

# %%
df['Country'] = df['Country'].str.strip()

# %%
df['Country'].value_counts()
# Out:
# Country
# USA               184
# UK                140
# Canada            132
# Australia          70
# India              68
# Brazil             17
# France             16
# Japan              15
# Germany            14
# Italy              11
# South Africa        6
# Greece              5
# Spain               5
# Netherlands         4
# Sweden              2
# Portugal            2
# Switzerland         2
# Belgium             2
# Denmark             2
# Czech Republic      2
# Austria             1
# Jordan              1
# Peru                1
# Maldives            1
# China               1
# Cambodia            1
# Norway              1
# Colombia            1
# Ireland             1
# Jamaica             1
# Kenya               1
# Scotland            1
# Thailand            1
# Name: count, dtype: int64

# %%
df['Platform'].unique()
# Out:
# array([' Twitter  ', ' Instagram ', ' Facebook ', ' Twitter '],
#       dtype=object)

# %%
df['Platform'] = df['Platform'].str.strip()

# %%
pd.set_option('display.max_rows', None)

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive                 44
# Joy                      42
# Excitement               32
# Neutral                  14
# Happy                    14
# Contentment              13
# Gratitude                 9
# Sad                       9
# Curiosity                 8
# Embarrassed               8
# Hate                      6
# Hopeful                   6
# Despair                   6
# Elation                   6
# Bad                       6
# Loneliness                6
# Confusion                 5
# Numbness                  5
# Melancholy                5
# Nostalgia                 5
# Ambivalence               5
# Indifference              5
# Contentment               5
# Serenity                  5
# Empowerment               5
# Gratitude                 5
# Serenity                  5
# Acceptance                5
# Determination             5
# Enthusiasm                5
# Bitterness                5
# Frustrated                5
# Curiosity                 5
# Euphoria                  4
# Excitement                4
# Hope                      4
# Neutral                   4
# Negative                  4
# Awe                       4
# Arousal                   4
# Serenity                  4
# Tenderness                4
# Grief                     4
# Betrayal                  4
# Desolation                4
# Nostalgia                 4
# Inspiration               4
# Frustration               4
# Boredom                   3
# Bitter                    3
# Acceptance                3
# Inspired                  3
# Grateful                  3
# Playful                   3
# Compassionate             3
# Jealous                   3
# Devastated                3
# Grief                     3
# Compassion                3
# Accomplishment            3
# Resentment                3
# Envious                   3
# Dismissive                3
# Overwhelmed               3
# Fearful                   3
# Kind                      3
# Calmness                  3
# Pride                     3
# Pride                     3
# Regret                    3
# Adventure                 3
# Surprise                  3
# Free-spirited             2
# Love                      2
# Awe                       2
# Disappointed              2
# Surprise                  2
# Adoration                 2
# Admiration                2
# Anticipation              2
# Empathetic                2
# Enjoyment                 2
# Amusement                 2
# Envy                      2
# Affection                 2
# Apprehensive              2
# Determination             2
# Reverence                 2
# Reflection                2
# Contemplation             2
# Despair                   2
# Frustration               2
# Jealousy                  2
# Fulfillment               2
# Reverence                 2
# Yearning                  2
# Confident                 2
# Zest                      2
# Fulfillment               2
# Proud                     2
# Enchantment               2
# Exploration               2
# Shame                     2
# Whimsy                    2
# Despair                   2
# Grief                     2
# Isolation                 2
# Enchantment               2
# Heartbreak                2
# Disappointment            2
# Loss                      2
# Awe                       2
# Regret                    2
# Mischievous               2
# Disgust                   2
# Joy                       2
# Sadness                   2
# Disgust                   2
# Happiness                 2
# Reflection                2
# Anger                     2
# Satisfaction              2
# Fear                      2
# Happiness                 2
# Confusion                 2
# Thrill                    2
# Enthusiasm                2
# Captivation               2
# Tranquility               2
# Emotion                   2
# Creativity                2
# Inspiration               1
# Intimidation              1
# Helplessness              1
# Boredom                   1
# Nature's Beauty           1
# Celestial Wonder          1
# Anxiety                   1
# Despair                   1
# Helplessness              1
# Relief                    1
# Anxiety                   1
# Intimidation              1
# Disgust                   1
# Indifference              1
# Positive                  1
# Creative Inspiration      1
# Runway Creativity         1
# Ocean's Freedom           1
# Whispers of the Past      1
# Jealousy                  1
# Curiosity                 1
# Loneliness                1
# Elation                   1
# Compassion                1
# Pride                     1
# Happiness                 1
# Amusement                 1
# JoyfulReunion             1
# Anticipation              1
# Blessed                   1
# Appreciation              1
# Nostalgia                 1
# Confidence                1
# Surprise                  1
# Wonderment                1
# Optimism                  1
# Motivation                1
# Excitement                1
# Satisfaction              1
# Numbness                  1
# Ambivalence               1
# Awe                       1
# Nostalgia                 1
# Thrill                    1
# Calmness                  1
# Overwhelmed               1
# Gratitude                 1
# Bittersweet               1
# Curiosity                 1
# Admiration                1
# Overjoyed                 1
# Mindfulness               1
# Euphoria                  1
# CulinaryOdyssey           1
# Inspiration               1
# Wonder                    1
# Radiance                  1
# ArtisticBurst             1
# Harmony                   1
# Adrenaline                1
# Heartbreak                1
# Serenity                  1
# Marvel                    1
# Curiosity                 1
# Gratitude                 1
# DreamChaser               1
# PlayfulJoy                1
# Intrigue                  1
# Gratitude                 1
# Coziness                  1
# Euphoria                  1
# Melodic                   1
# FestiveJoy                1
# InnerJourney              1
# Freedom                   1
# Dazzle                    1
# Thrill                    1
# Harmony                   1
# Creativity                1
# Radiance                  1
# Wonder                    1
# Rejuvenation              1
# Elegance                  1
# Pensive                   1
# Solitude                  1
# Heartache                 1
# Resilience                1
# Sorrow                    1
# Sorrow                    1
# Darkness                  1
# Desperation               1
# Ruins                     1
# Exhaustion                1
# Melancholy                1
# LostLove                  1
# Loneliness                1
# Betrayal                  1
# Suffering                 1
# EmotionalStorm            1
# Regret                    1
# Spark                     1
# Immersion                 1
# Resilience                1
# Positivity                1
# Shame                     1
# Confusion                 1
# Love                      1
# Amazement                 1
# Grandeur                  1
# Wonder                    1
# Celebration               1
# Energy                    1
# Friendship                1
# Kindness                  1
# Romance                   1
# Success                   1
# Colorful                  1
# Hope                      1
# Ecstasy                   1
# Charm                     1
# Euphoria                  1
# Journey                   1
# Connection                1
# Hypnotic                  1
# Touched                   1
# Suspense                  1
# Admiration                1
# Triumph                   1
# Heartwarming              1
# Obstacle                  1
# Engagement                1
# Iconic                    1
# Pressure                  1
# Sympathy                  1
# Renewed Effort            1
# Miscalculation            1
# Breakthrough              1
# Harmony                   1
# Challenge                 1
# Solace                    1
# Envisioning History       1
# Joy in Baking             1
# Imagination               1
# Vibrancy                  1
# Culinary Adventure        1
# Mesmerizing               1
# Thrilling Journey         1
# Winter Magic              1
# Name: count, dtype: int64

# %%
df['Sentiment'].value_counts().shape
# Out:
# (279,)

# %%
# convert all texts to lowercase & strip the white spaces in the 'Sentiment' column
df['Sentiment'] = df['Sentiment'].str.lower()
df['Sentiment'] = df['Sentiment'].str.strip()
df['Sentiment'].value_counts().shape
# Out:
# (191,)

# %%
# Basic text cleaning
import re

# %%
def clean_text(text):
    text = re.sub(r"http\S+|@\S+|#\S+", "", text)   # remove URLs, mentions, hashtags
    text = re.sub(r"[^A-Za-z\s]", "", text.lower()) # remove punctuation, numbers, lower
    return text

df['Clean_Text'] = df['Text'].apply(clean_text)

# %%
df['Clean_Text'].head()
# Out:
# 0     enjoying a beautiful day at the park         ...
# 1     traffic was terrible this morning            ...
# 2     just finished an amazing workout
# 3     excited about the upcoming weekend getaway   ...
# 4     trying out a new recipe for dinner tonight   ...
# Name: Clean_Text, dtype: object

# %% [markdown]
# #  EDA (Exploratory Data Analysis)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Top 10 Sentiments in Social Media
plt.figure(figsize=(10,4))
sns.countplot(x='Sentiment', data=df, order=df['Sentiment'].value_counts().index[:10], palette='viridis')
plt.xticks(rotation=45)
plt.title("Sentiment Distribution")
plt.show()
# Out:
# C:\Users\CHANDAN\AppData\Local\Temp\ipykernel_11672\708888545.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sentiment', data=df, order=df['Sentiment'].value_counts().index[:10], palette='viridis')

# %% [markdown]
# # Now there are over 190 distinct sentiments in our dataset.
# ## Many sentiments are listed in the dataset, but can they be categorized into three main sentiment groups: positive, neural, and negative?

# %%
# Sentiment by month
df.groupby('Month')['Sentiment'].value_counts().unstack().plot(
    kind='bar', 
    stacked=True, 
    figsize=(12, 6), 
    colormap='viridis', 
    edgecolor='black'
)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Monthly Sentiment Trend', fontsize=14)
plt.legend(title='Sentiment', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.title('Monthly Sentiment Trend')
plt.show()
# Out:
# C:\Users\CHANDAN\AppData\Local\Temp\ipykernel_11672\714983485.py:13: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Posts per hour
df.groupby('Hour').size().plot(kind='line')
plt.title('Posting Activity by Hour')
plt.show()

# %% [markdown]
# # Nature of Sentiment Analysis (attributing to'positive', 'negative', 'neutral')
# ## Many sentiments are listed in the dataset, but can they be categorized into three main sentiment groups: positive, neural, and negative?

# %%
df1 = df.copy()
df1.head()
# Out:
#                                                 Text Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...  positive
# 1   Traffic was terrible this morning.           ...  negative
# 2   Just finished an amazing workout! 💪          ...  positive
# 3   Excited about the upcoming weekend getaway!  ...  positive
# 4   Trying out a new recipe for dinner tonight.  ...   neutral
#
#             Timestamp            User   Platform  \
# 0 2023-01-15 12:30:00   User123          Twitter
# 1 2023-01-15 08:45:00   CommuterX        Twitter
# 2 2023-01-15 15:45:00   FitnessFan     Instagram
# 3 2023-01-15 18:20:00   AdventureX      Facebook
# 4 2023-01-15 19:55:00   ChefCook       Instagram
#
#                                      Hashtags  Retweets  Likes    Country  \
# 0   #Nature #Park                                  15.0   30.0        USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# 2   #Fitness #Workout                              20.0   40.0        USA
# 3   #Travel #Adventure                              8.0   15.0         UK
# 4   #Cooking #Food                                 12.0   25.0  Australia
#
#    Year    Month  Day  Hour Day_of_week  \
# 0  2023  January   15    12      Sunday
# 1  2023  January   15     8      Sunday
# 2  2023  January   15    15      Sunday
# 3  2023  January   15    18      Sunday
# 4  2023  January   15    19      Sunday
#
#                                           Clean_Text
# 0   enjoying a beautiful day at the park         ...
# 1   traffic was terrible this morning            ...
# 2   just finished an amazing workout
# 3   excited about the upcoming weekend getaway   ...
# 4   trying out a new recipe for dinner tonight   ...

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\CHANDAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
# first analyzing 'sentiment' column's sentiment using Vader and give each sentiment a score
analyzer = SentimentIntensityAnalyzer()
df1['Sentiment_Score'] = df1['Sentiment'].apply(lambda x: analyzer.polarity_scores(x)['compound'])

# %%
# based on the sentiment score of each sentiment, if 'compound' score is >= 0.05, then it is positive, if <= -0.05, then it is negative, else it is neutral
df1['Sentiment_Nature'] = df1['Sentiment_Score'].apply(lambda x: 'positive' if x >= 0.05 else 'negative' if x <= -0.05 else 'neutral')
df1.head(60)
# Out:
#                                                  Text  Sentiment  \
# 0    Enjoying a beautiful day at the park!        ...   positive
# 1    Traffic was terrible this morning.           ...   negative
# 2    Just finished an amazing workout! 💪          ...   positive
# 3    Excited about the upcoming weekend getaway!  ...   positive
# 4    Trying out a new recipe for dinner tonight.  ...    neutral
# 5    Feeling grateful for the little things in lif...   positive
# 6    Rainy days call for cozy blankets and hot coc...   positive
# 7    The new movie release is a must-watch!       ...   positive
# 8    Political discussions heating up on the timel...   negative
# 9    Missing summer vibes and beach days.         ...    neutral
# 10   Just published a new blog post. Check it out!...   positive
# 11   Feeling a bit under the weather today.       ...   negative
# 12   Exploring the city's hidden gems.            ...   positive
# 13   New year, new fitness goals! 💪               ...   positive
# 14   Technology is changing the way we live.      ...    neutral
# 15   Reflecting on the past and looking ahead.    ...   positive
# 16   Just adopted a cute furry friend! 🐾          ...   positive
# 17   Late-night gaming session with friends.      ...   positive
# 18   Attending a virtual conference on AI.        ...    neutral
# 19   Winter blues got me feeling low.             ...   negative
# 20   Sipping coffee and enjoying a good book.     ...   positive
# 21   Exploring the world of virtual reality.      ...   positive
# 22   Productive day ticking off my to-do list.    ...   positive
# 23   Just finished a challenging workout routine. ...   positive
# 24   Celebrating a milestone at work! 🎉           ...   positive
# 25   Sunday brunch with friends.                  ...   positive
# 26   Learning a new language for personal growth. ...   positive
# 27   Quiet evening with a good book.              ...   positive
# 28   Reflecting on the importance of mental health...   positive
# 29   New painting in progress! 🎨                  ...   positive
# 30   Weekend road trip to explore scenic views.   ...   positive
# 31   Enjoying a cup of tea and watching the sunset...   positive
# 32   Coding a new project with enthusiasm.        ...   positive
# 33   Feeling inspired after attending a workshop. ...   positive
# 34   Winter sports day at the local park.         ...   positive
# 35   Quality time with family this weekend.       ...   positive
# 36   Attending a live music concert tonight.      ...   positive
# 37   Practicing mindfulness with meditation.      ...   positive
# 38   Trying out a new dessert recipe.             ...   positive
# 39   Excited about the upcoming gaming tournament....   positive
# 40   Planning a garden makeover for spring.       ...   positive
# 41   Celebrating a friend's birthday tonight! 🎂   ...   positive
# 42   Feeling accomplished after a productive day. ...   positive
# 43   A cozy evening with a good movie.            ...   positive
# 44   Exploring local art galleries this weekend.  ...   positive
# 45   New book release from my favorite author!    ...   positive
# 46   Attending a virtual reality meetup.          ...   positive
# 47   Reflecting on the beauty of nature.          ...   positive
# 48   Cooking a special dinner for loved ones.     ...   positive
# 49   Feeling optimistic about the week ahead.     ...   positive
# 50   Starting a new fitness challenge tomorrow! 💪 ...   positive
# 51   Sunday bike ride through scenic trails.      ...   positive
# 52   Can't believe the injustice happening in our ...      anger
# 53   Feeling a sense of fear after watching a thri...       fear
# 54   Heartbroken after hearing the news about a na...    sadness
# 55   The state of the world's environment is just ...    disgust
# 56   Pure happiness: celebrating a loved one's ach...  happiness
# 57   Laughter is the best medicine—enjoying a come...        joy
# 58   Sharing love and positive vibes with everyone...       love
# 59   An amusing incident brightened up my day!    ...  amusement
#
#              Timestamp                  User   Platform  \
# 0  2023-01-15 12:30:00         User123          Twitter
# 1  2023-01-15 08:45:00         CommuterX        Twitter
# 2  2023-01-15 15:45:00         FitnessFan     Instagram
# 3  2023-01-15 18:20:00         AdventureX      Facebook
# 4  2023-01-15 19:55:00         ChefCook       Instagram
# 5  2023-01-16 09:10:00         GratitudeNow     Twitter
# 6  2023-01-16 14:45:00         RainyDays       Facebook
# 7  2023-01-16 19:30:00         MovieBuff      Instagram
# 8  2023-01-17 08:00:00         DebateTalk       Twitter
# 9  2023-01-17 12:20:00         BeachLover      Facebook
# 10 2023-01-17 15:15:00         BloggerX       Instagram
# 11 2023-01-18 10:30:00         WellnessCheck    Twitter
# 12 2023-01-18 14:50:00         UrbanExplorer   Facebook
# 13 2023-01-18 18:00:00         FitJourney     Instagram
# 14 2023-01-19 09:45:00        TechEnthusiast    Twitter
# 15 2023-01-19 13:20:00         Reflections     Facebook
# 16 2023-01-19 17:10:00         PetAdopter     Instagram
# 17 2023-01-20 00:05:00         GamerX           Twitter
# 18 2023-01-20 11:30:00        TechConference   Facebook
# 19 2023-01-20 15:15:00         WinterBlues    Instagram
# 20 2023-01-21 08:40:00         Bookworm         Twitter
# 21 2023-01-21 13:20:00         VRExplorer      Facebook
# 22 2023-01-21 16:45:00       ProductivityPro  Instagram
# 23 2023-01-22 09:15:00        FitnessWarrior    Twitter
# 24 2023-01-22 14:30:00       CareerMilestone   Facebook
# 25 2023-01-22 12:00:00         BrunchBuddy    Instagram
# 26 2023-01-23 16:20:00       LanguageLearner   Facebook
# 27 2023-01-23 19:45:00         BookLover      Instagram
# 28 2023-01-24 11:30:00   MentalHealthMatters    Twitter
# 29 2023-01-24 15:00:00        ArtistInAction   Facebook
# 30 2023-01-24 17:30:00         RoadTripper    Instagram
# 31 2023-01-25 18:00:00         SunsetWatcher    Twitter
# 32 2023-01-25 13:15:00        CodeEnthusiast   Facebook
# 33 2023-01-26 09:45:00      WorkshopAttendee  Instagram
# 34 2023-01-26 14:20:00        WinterSports      Twitter
# 35 2023-01-26 17:40:00         FamilyTime      Facebook
# 36 2023-01-27 20:00:00         MusicLover     Instagram
# 37 2023-01-27 12:30:00        MindfulMoments    Twitter
# 38 2023-01-27 16:10:00       DessertExplorer   Facebook
# 39 2023-01-28 09:00:00      GamingEnthusiast  Instagram
# 40 2023-01-28 14:45:00        GardenPlanner     Twitter
# 41 2023-01-28 19:30:00         BirthdayBash    Facebook
# 42 2023-01-29 17:00:00       ProductivityWin  Instagram
# 43 2023-01-29 20:20:00         MovieNight       Twitter
# 44 2023-01-30 11:30:00         ArtExplorer     Facebook
# 45 2023-01-30 15:45:00         BookwormX      Instagram
# 46 2023-01-30 18:30:00         VRMeetup         Twitter
# 47 2023-01-31 10:45:00         NatureLover     Facebook
# 48 2023-01-31 19:00:00         ChefAtHome     Instagram
# 49 2023-01-31 16:20:00     OptimisticMindset    Twitter
# 50 2023-02-01 08:00:00      FitnessChallenge   Facebook
# 51 2023-02-01 13:30:00        BikeExplorer    Instagram
# 52 2023-02-11 09:30:00      SocialJustice       Twitter
# 53 2023-02-11 21:15:00      ThrillerFan       Instagram
# 54 2023-02-12 14:45:00      EmpathyFirst       Facebook
# 55 2023-02-12 18:20:00      EcoAwareness        Twitter
# 56 2023-02-13 10:00:00      ProudFriend       Instagram
# 57 2023-02-13 19:30:00      ComedyFan          Facebook
# 58 2023-02-14 08:30:00      LoveSpreader        Twitter
# 59 2023-02-14 14:20:00      AmusedSoul        Instagram
#
#                                           Hashtags  Retweets  Likes  \
# 0        #Nature #Park                                  15.0   30.0
# 1        #Traffic #Morning                               5.0   10.0
# 2        #Fitness #Workout                              20.0   40.0
# 3        #Travel #Adventure                              8.0   15.0
# 4        #Cooking #Food                                 12.0   25.0
# 5          #Gratitude #PositiveVibes                    25.0   50.0
# 6        #RainyDays #Cozy                               10.0   20.0
# 7         #MovieNight #MustWatch                        15.0   30.0
# 8         #Politics #Debate                             30.0   60.0
# 9         #Summer #BeachDays                            18.0   35.0
# 10        #Blogging #NewPost                            22.0   45.0
# 11        #SickDay #Health                               7.0   15.0
# 12        #CityExplore #HiddenGems                      12.0   25.0
# 13        #NewYear #FitnessGoals                        28.0   55.0
# 14        #Tech #Innovation                             15.0   30.0
# 15        #Reflection #Future                           20.0   40.0
# 16        #PetAdoption #FurryFriend                     15.0   30.0
# 17        #Gaming #LateNight                            18.0   35.0
# 18        #AI #TechConference                           25.0   50.0
# 19        #WinterBlues #Mood                             8.0   15.0
# 20        #Reading #CoffeeTime                          22.0   45.0
# 21        #VR #VirtualReality                           15.0   30.0
# 22          #Productivity #WorkFromHome                 30.0   60.0
# 23        #Fitness #ChallengeAccepted                   20.0   40.0
# 24        #Career #Milestone                            12.0   25.0
# 25         #Brunch #Friends                             15.0   30.0
# 26        #LanguageLearning #PersonalGrowth             25.0   50.0
# 27        #Reading #QuietTime                           15.0   30.0
# 28        #MentalHealth #SelfCare                       22.0   45.0
# 29           #Art #PaintingInProgress                   12.0   25.0
# 30        #RoadTrip #ScenicViews                        18.0   35.0
# 31         #TeaTime #Sunset                             15.0   30.0
# 32          #Coding #Enthusiasm                         30.0   60.0
# 33        #Inspiration #Workshop                        25.0   50.0
# 34         #WinterSports #Fun                           15.0   30.0
# 35        #FamilyTime #Weekend                          22.0   45.0
# 36          #Music #ConcertNight                        18.0   35.0
# 37         #Mindfulness #Meditation                     15.0   30.0
# 38         #Dessert #Cooking                            12.0   25.0
# 39        #Gaming #Tournament                           30.0   60.0
# 40         #Gardening #Spring                           25.0   50.0
# 41        #Birthday #Celebration                        15.0   30.0
# 42           #Accomplished #Success                     22.0   45.0
# 43        #CozyNight #MovieTime                         18.0   35.0
# 44        #Art #GalleryExplore                          15.0   30.0
# 45         #BookRelease #FavoriteAuthor                 12.0   25.0
# 46        #VRMeetup #VirtualReality                     28.0   55.0
# 47        #Nature #Reflection                           15.0   30.0
# 48         #Cooking #SpecialDinner                      20.0   40.0
# 49         #Optimism #NewWeek                           15.0   30.0
# 50         #FitnessChallenge #NewBeginnings             22.0   45.0
# 51         #BikeRide #ScenicTrails                      18.0   35.0
# 52   #Injustice #Angry                                  20.0   40.0
# 53   #Fear #ThrillerMovie                               15.0   30.0
# 54   #Sadness #NaturalDisaster                          25.0   50.0
# 55   #Disgust #Environment                              18.0   35.0
# 56      #Happiness #Celebration                         30.0   60.0
# 57   #Joy #ComedyShow                                   22.0   45.0
# 58   #Love #SpreadLove                                  15.0   30.0
# 59   #Amusement #FunTimes                               18.0   35.0
#
#       Country  Year     Month  Day  Hour Day_of_week  \
# 0         USA  2023   January   15    12      Sunday
# 1      Canada  2023   January   15     8      Sunday
# 2         USA  2023   January   15    15      Sunday
# 3          UK  2023   January   15    18      Sunday
# 4   Australia  2023   January   15    19      Sunday
# 5       India  2023   January   16     9      Monday
# 6      Canada  2023   January   16    14      Monday
# 7         USA  2023   January   16    19      Monday
# 8         USA  2023   January   17     8     Tuesday
# 9   Australia  2023   January   17    12     Tuesday
# 10        USA  2023   January   17    15     Tuesday
# 11     Canada  2023   January   18    10   Wednesday
# 12         UK  2023   January   18    14   Wednesday
# 13        USA  2023   January   18    18   Wednesday
# 14      India  2023   January   19     9    Thursday
# 15        USA  2023   January   19    13    Thursday
# 16     Canada  2023   January   19    17    Thursday
# 17         UK  2023   January   20     0      Friday
# 18        USA  2023   January   20    11      Friday
# 19        USA  2023   January   20    15      Friday
# 20      India  2023   January   21     8    Saturday
# 21        USA  2023   January   21    13    Saturday
# 22        USA  2023   January   21    16    Saturday
# 23         UK  2023   January   22     9      Sunday
# 24     Canada  2023   January   22    14      Sunday
# 25         UK  2023   January   22    12      Sunday
# 26      India  2023   January   23    16      Monday
# 27  Australia  2023   January   23    19      Monday
# 28        USA  2023   January   24    11     Tuesday
# 29     Canada  2023   January   24    15     Tuesday
# 30         UK  2023   January   24    17     Tuesday
# 31      India  2023   January   25    18   Wednesday
# 32        USA  2023   January   25    13   Wednesday
# 33        USA  2023   January   26     9    Thursday
# 34     Canada  2023   January   26    14    Thursday
# 35         UK  2023   January   26    17    Thursday
# 36        USA  2023   January   27    20      Friday
# 37      India  2023   January   27    12      Friday
# 38     Canada  2023   January   27    16      Friday
# 39        USA  2023   January   28     9    Saturday
# 40        USA  2023   January   28    14    Saturday
# 41         UK  2023   January   28    19    Saturday
# 42      India  2023   January   29    17      Sunday
# 43     Canada  2023   January   29    20      Sunday
# 44        USA  2023   January   30    11      Monday
# 45         UK  2023   January   30    15      Monday
# 46      India  2023   January   30    18      Monday
# 47  Australia  2023   January   31    10     Tuesday
# 48        USA  2023   January   31    19     Tuesday
# 49     Canada  2023   January   31    16     Tuesday
# 50         UK  2023  February    1     8   Wednesday
# 51        USA  2023  February    1    13   Wednesday
# 52     Canada  2023  February   11     9    Saturday
# 53        USA  2023  February   11    21    Saturday
# 54      India  2023  February   12    14      Sunday
# 55         UK  2023  February   12    18      Sunday
# 56        USA  2023  February   13    10      Monday
# 57     Canada  2023  February   13    19      Monday
# 58  Australia  2023  February   14     8     Tuesday
# 59         UK  2023  February   14    14     Tuesday
#
#                                            Clean_Text  Sentiment_Score  \
# 0    enjoying a beautiful day at the park         ...           0.5574
# 1    traffic was terrible this morning            ...          -0.5719
# 2    just finished an amazing workout                           0.5574
# 3    excited about the upcoming weekend getaway   ...           0.5574
# 4    trying out a new recipe for dinner tonight   ...           0.0000
# 5    feeling grateful for the little things in lif...           0.5574
# 6    rainy days call for cozy blankets and hot coc...           0.5574
# 7    the new movie release is a mustwatch         ...           0.5574
# 8    political discussions heating up on the timel...          -0.5719
# 9    missing summer vibes and beach days          ...           0.0000
# 10   just published a new blog post check it out  ...           0.5574
# 11   feeling a bit under the weather today        ...          -0.5719
# 12   exploring the citys hidden gems              ...           0.5574
# 13    new year new fitness goals                                0.5574
# 14   technology is changing the way we live       ...           0.0000
# 15   reflecting on the past and looking ahead     ...           0.5574
# 16    just adopted a cute furry friend                          0.5574
# 17   latenight gaming session with friends        ...           0.5574
# 18   attending a virtual conference on ai         ...           0.0000
# 19   winter blues got me feeling low              ...          -0.5719
# 20   sipping coffee and enjoying a good book      ...           0.5574
# 21   exploring the world of virtual reality       ...           0.5574
# 22   productive day ticking off my todo list      ...           0.5574
# 23   just finished a challenging workout routine  ...           0.5574
# 24    celebrating a milestone at work                           0.5574
# 25   sunday brunch with friends                   ...           0.5574
# 26   learning a new language for personal growth  ...           0.5574
# 27   quiet evening with a good book               ...           0.5574
# 28   reflecting on the importance of mental health...           0.5574
# 29   new painting in progress                                   0.5574
# 30   weekend road trip to explore scenic views    ...           0.5574
# 31   enjoying a cup of tea and watching the sunset...           0.5574
# 32   coding a new project with enthusiasm         ...           0.5574
# 33   feeling inspired after attending a workshop  ...           0.5574
# 34   winter sports day at the local park          ...           0.5574
# 35   quality time with family this weekend        ...           0.5574
# 36   attending a live music concert tonight       ...           0.5574
# 37   practicing mindfulness with meditation       ...           0.5574
# 38   trying out a new dessert recipe              ...           0.5574
# 39   excited about the upcoming gaming tournament ...           0.5574
# 40   planning a garden makeover for spring        ...           0.5574
# 41     celebrating a friends birthday tonight                   0.5574
# 42   feeling accomplished after a productive day  ...           0.5574
# 43   a cozy evening with a good movie             ...           0.5574
# 44   exploring local art galleries this weekend   ...           0.5574
# 45   new book release from my favorite author     ...           0.5574
# 46   attending a virtual reality meetup           ...           0.5574
# 47   reflecting on the beauty of nature           ...           0.5574
# 48   cooking a special dinner for loved ones      ...           0.5574
# 49   feeling optimistic about the week ahead      ...           0.5574
# 50    starting a new fitness challenge tomorrow                 0.5574
# 51   sunday bike ride through scenic trails       ...           0.5574
# 52   cant believe the injustice happening in our s...          -0.5719
# 53   feeling a sense of fear after watching a thri...          -0.4939
# 54   heartbroken after hearing the news about a na...          -0.4404
# 55   the state of the worlds environment is just d...          -0.5994
# 56   pure happiness celebrating a loved ones achie...           0.5574
# 57   laughter is the best medicineenjoying a comed...           0.5859
# 58   sharing love and positive vibes with everyone...           0.6369
# 59   an amusing incident brightened up my day     ...           0.3612
#
#    Sentiment_Nature
# 0          positive
# 1          negative
# 2          positive
# 3          positive
# 4           neutral
# 5          positive
# 6          positive
# 7          positive
# 8          negative
# 9           neutral
# 10         positive
# 11         negative
# 12         positive
# 13         positive
# 14          neutral
# 15         positive
# 16         positive
# 17         positive
# 18          neutral
# 19         negative
# 20         positive
# 21         positive
# 22         positive
# 23         positive
# 24         positive
# 25         positive
# 26         positive
# 27         positive
# 28         positive
# 29         positive
# 30         positive
# 31         positive
# 32         positive
# 33         positive
# 34         positive
# 35         positive
# 36         positive
# 37         positive
# 38         positive
# 39         positive
# 40         positive
# 41         positive
# 42         positive
# 43         positive
# 44         positive
# 45         positive
# 46         positive
# 47         positive
# 48         positive
# 49         positive
# 50         positive
# 51         positive
# 52         negative
# 53         negative
# 54         negative
# 55         negative
# 56         positive
# 57         positive
# 58         positive
# 59         positive

# %%
# defining punctuation and stopwords
import string
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
punctuation = string.punctuation
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\CHANDAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# function to remove stopwords and punctuation from the text
def remove_stopwords_and_punctuation(text):
    text = text.lower()
    text = ''.join([char for char in text if char not in punctuation])
    text = ' '.join([word for word in text.split() if word not in stop_words])
    return text

# applying the function to the 'Text' column
df1['Cleaned_Text'] = df1['Text'].apply(remove_stopwords_and_punctuation)
df1['Cleaned_Text'].head(10)
# Out:
# 0                enjoying beautiful day park
# 1                   traffic terrible morning
# 2                 finished amazing workout 💪
# 3           excited upcoming weekend getaway
# 4           trying new recipe dinner tonight
# 5        feeling grateful little things life
# 6    rainy days call cozy blankets hot cocoa
# 7                new movie release mustwatch
# 8     political discussions heating timeline
# 9            missing summer vibes beach days
# Name: Cleaned_Text, dtype: object

# %%
# ensuring all values in the 'Text' column are strings
df1['Text'] = df1['Text'].astype(str)

# %%
# remove punctuation (except '?' and '!'), convert to lowercase, and remove stopwords
df1['Cleaned_Text'] = df1['Text'].str.replace(r'[^\w\s?!]', '', regex=True).str.lower()

# %%
# analyzing the 'Cleaned_Text' column's sentiment  and giving each sentiment a score
df1['Text_Sentiment_Score'] = df1['Cleaned_Text'].apply(lambda x: analyzer.polarity_scores(x)['compound'])

# %%
# giving sentiment nature based on the score of each sentiment
df1['Text_Sentiment_Nature'] = df1['Text_Sentiment_Score'].apply(lambda x: 'positive' if x >= 0.05 else 'negative' if x <= -0.05 else 'neutral')
df1.head(60)
# Out:
#                                                  Text  Sentiment  \
# 0    Enjoying a beautiful day at the park!        ...   positive
# 1    Traffic was terrible this morning.           ...   negative
# 2    Just finished an amazing workout! 💪          ...   positive
# 3    Excited about the upcoming weekend getaway!  ...   positive
# 4    Trying out a new recipe for dinner tonight.  ...    neutral
# 5    Feeling grateful for the little things in lif...   positive
# 6    Rainy days call for cozy blankets and hot coc...   positive
# 7    The new movie release is a must-watch!       ...   positive
# 8    Political discussions heating up on the timel...   negative
# 9    Missing summer vibes and beach days.         ...    neutral
# 10   Just published a new blog post. Check it out!...   positive
# 11   Feeling a bit under the weather today.       ...   negative
# 12   Exploring the city's hidden gems.            ...   positive
# 13   New year, new fitness goals! 💪               ...   positive
# 14   Technology is changing the way we live.      ...    neutral
# 15   Reflecting on the past and looking ahead.    ...   positive
# 16   Just adopted a cute furry friend! 🐾          ...   positive
# 17   Late-night gaming session with friends.      ...   positive
# 18   Attending a virtual conference on AI.        ...    neutral
# 19   Winter blues got me feeling low.             ...   negative
# 20   Sipping coffee and enjoying a good book.     ...   positive
# 21   Exploring the world of virtual reality.      ...   positive
# 22   Productive day ticking off my to-do list.    ...   positive
# 23   Just finished a challenging workout routine. ...   positive
# 24   Celebrating a milestone at work! 🎉           ...   positive
# 25   Sunday brunch with friends.                  ...   positive
# 26   Learning a new language for personal growth. ...   positive
# 27   Quiet evening with a good book.              ...   positive
# 28   Reflecting on the importance of mental health...   positive
# 29   New painting in progress! 🎨                  ...   positive
# 30   Weekend road trip to explore scenic views.   ...   positive
# 31   Enjoying a cup of tea and watching the sunset...   positive
# 32   Coding a new project with enthusiasm.        ...   positive
# 33   Feeling inspired after attending a workshop. ...   positive
# 34   Winter sports day at the local park.         ...   positive
# 35   Quality time with family this weekend.       ...   positive
# 36   Attending a live music concert tonight.      ...   positive
# 37   Practicing mindfulness with meditation.      ...   positive
# 38   Trying out a new dessert recipe.             ...   positive
# 39   Excited about the upcoming gaming tournament....   positive
# 40   Planning a garden makeover for spring.       ...   positive
# 41   Celebrating a friend's birthday tonight! 🎂   ...   positive
# 42   Feeling accomplished after a productive day. ...   positive
# 43   A cozy evening with a good movie.            ...   positive
# 44   Exploring local art galleries this weekend.  ...   positive
# 45   New book release from my favorite author!    ...   positive
# 46   Attending a virtual reality meetup.          ...   positive
# 47   Reflecting on the beauty of nature.          ...   positive
# 48   Cooking a special dinner for loved ones.     ...   positive
# 49   Feeling optimistic about the week ahead.     ...   positive
# 50   Starting a new fitness challenge tomorrow! 💪 ...   positive
# 51   Sunday bike ride through scenic trails.      ...   positive
# 52   Can't believe the injustice happening in our ...      anger
# 53   Feeling a sense of fear after watching a thri...       fear
# 54   Heartbroken after hearing the news about a na...    sadness
# 55   The state of the world's environment is just ...    disgust
# 56   Pure happiness: celebrating a loved one's ach...  happiness
# 57   Laughter is the best medicine—enjoying a come...        joy
# 58   Sharing love and positive vibes with everyone...       love
# 59   An amusing incident brightened up my day!    ...  amusement
#
#              Timestamp                  User   Platform  \
# 0  2023-01-15 12:30:00         User123          Twitter
# 1  2023-01-15 08:45:00         CommuterX        Twitter
# 2  2023-01-15 15:45:00         FitnessFan     Instagram
# 3  2023-01-15 18:20:00         AdventureX      Facebook
# 4  2023-01-15 19:55:00         ChefCook       Instagram
# 5  2023-01-16 09:10:00         GratitudeNow     Twitter
# 6  2023-01-16 14:45:00         RainyDays       Facebook
# 7  2023-01-16 19:30:00         MovieBuff      Instagram
# 8  2023-01-17 08:00:00         DebateTalk       Twitter
# 9  2023-01-17 12:20:00         BeachLover      Facebook
# 10 2023-01-17 15:15:00         BloggerX       Instagram
# 11 2023-01-18 10:30:00         WellnessCheck    Twitter
# 12 2023-01-18 14:50:00         UrbanExplorer   Facebook
# 13 2023-01-18 18:00:00         FitJourney     Instagram
# 14 2023-01-19 09:45:00        TechEnthusiast    Twitter
# 15 2023-01-19 13:20:00         Reflections     Facebook
# 16 2023-01-19 17:10:00         PetAdopter     Instagram
# 17 2023-01-20 00:05:00         GamerX           Twitter
# 18 2023-01-20 11:30:00        TechConference   Facebook
# 19 2023-01-20 15:15:00         WinterBlues    Instagram
# 20 2023-01-21 08:40:00         Bookworm         Twitter
# 21 2023-01-21 13:20:00         VRExplorer      Facebook
# 22 2023-01-21 16:45:00       ProductivityPro  Instagram
# 23 2023-01-22 09:15:00        FitnessWarrior    Twitter
# 24 2023-01-22 14:30:00       CareerMilestone   Facebook
# 25 2023-01-22 12:00:00         BrunchBuddy    Instagram
# 26 2023-01-23 16:20:00       LanguageLearner   Facebook
# 27 2023-01-23 19:45:00         BookLover      Instagram
# 28 2023-01-24 11:30:00   MentalHealthMatters    Twitter
# 29 2023-01-24 15:00:00        ArtistInAction   Facebook
# 30 2023-01-24 17:30:00         RoadTripper    Instagram
# 31 2023-01-25 18:00:00         SunsetWatcher    Twitter
# 32 2023-01-25 13:15:00        CodeEnthusiast   Facebook
# 33 2023-01-26 09:45:00      WorkshopAttendee  Instagram
# 34 2023-01-26 14:20:00        WinterSports      Twitter
# 35 2023-01-26 17:40:00         FamilyTime      Facebook
# 36 2023-01-27 20:00:00         MusicLover     Instagram
# 37 2023-01-27 12:30:00        MindfulMoments    Twitter
# 38 2023-01-27 16:10:00       DessertExplorer   Facebook
# 39 2023-01-28 09:00:00      GamingEnthusiast  Instagram
# 40 2023-01-28 14:45:00        GardenPlanner     Twitter
# 41 2023-01-28 19:30:00         BirthdayBash    Facebook
# 42 2023-01-29 17:00:00       ProductivityWin  Instagram
# 43 2023-01-29 20:20:00         MovieNight       Twitter
# 44 2023-01-30 11:30:00         ArtExplorer     Facebook
# 45 2023-01-30 15:45:00         BookwormX      Instagram
# 46 2023-01-30 18:30:00         VRMeetup         Twitter
# 47 2023-01-31 10:45:00         NatureLover     Facebook
# 48 2023-01-31 19:00:00         ChefAtHome     Instagram
# 49 2023-01-31 16:20:00     OptimisticMindset    Twitter
# 50 2023-02-01 08:00:00      FitnessChallenge   Facebook
# 51 2023-02-01 13:30:00        BikeExplorer    Instagram
# 52 2023-02-11 09:30:00      SocialJustice       Twitter
# 53 2023-02-11 21:15:00      ThrillerFan       Instagram
# 54 2023-02-12 14:45:00      EmpathyFirst       Facebook
# 55 2023-02-12 18:20:00      EcoAwareness        Twitter
# 56 2023-02-13 10:00:00      ProudFriend       Instagram
# 57 2023-02-13 19:30:00      ComedyFan          Facebook
# 58 2023-02-14 08:30:00      LoveSpreader        Twitter
# 59 2023-02-14 14:20:00      AmusedSoul        Instagram
#
#                                           Hashtags  Retweets  Likes  \
# 0        #Nature #Park                                  15.0   30.0
# 1        #Traffic #Morning                               5.0   10.0
# 2        #Fitness #Workout                              20.0   40.0
# 3        #Travel #Adventure                              8.0   15.0
# 4        #Cooking #Food                                 12.0   25.0
# 5          #Gratitude #PositiveVibes                    25.0   50.0
# 6        #RainyDays #Cozy                               10.0   20.0
# 7         #MovieNight #MustWatch                        15.0   30.0
# 8         #Politics #Debate                             30.0   60.0
# 9         #Summer #BeachDays                            18.0   35.0
# 10        #Blogging #NewPost                            22.0   45.0
# 11        #SickDay #Health                               7.0   15.0
# 12        #CityExplore #HiddenGems                      12.0   25.0
# 13        #NewYear #FitnessGoals                        28.0   55.0
# 14        #Tech #Innovation                             15.0   30.0
# 15        #Reflection #Future                           20.0   40.0
# 16        #PetAdoption #FurryFriend                     15.0   30.0
# 17        #Gaming #LateNight                            18.0   35.0
# 18        #AI #TechConference                           25.0   50.0
# 19        #WinterBlues #Mood                             8.0   15.0
# 20        #Reading #CoffeeTime                          22.0   45.0
# 21        #VR #VirtualReality                           15.0   30.0
# 22          #Productivity #WorkFromHome                 30.0   60.0
# 23        #Fitness #ChallengeAccepted                   20.0   40.0
# 24        #Career #Milestone                            12.0   25.0
# 25         #Brunch #Friends                             15.0   30.0
# 26        #LanguageLearning #PersonalGrowth             25.0   50.0
# 27        #Reading #QuietTime                           15.0   30.0
# 28        #MentalHealth #SelfCare                       22.0   45.0
# 29           #Art #PaintingInProgress                   12.0   25.0
# 30        #RoadTrip #ScenicViews                        18.0   35.0
# 31         #TeaTime #Sunset                             15.0   30.0
# 32          #Coding #Enthusiasm                         30.0   60.0
# 33        #Inspiration #Workshop                        25.0   50.0
# 34         #WinterSports #Fun                           15.0   30.0
# 35        #FamilyTime #Weekend                          22.0   45.0
# 36          #Music #ConcertNight                        18.0   35.0
# 37         #Mindfulness #Meditation                     15.0   30.0
# 38         #Dessert #Cooking                            12.0   25.0
# 39        #Gaming #Tournament                           30.0   60.0
# 40         #Gardening #Spring                           25.0   50.0
# 41        #Birthday #Celebration                        15.0   30.0
# 42           #Accomplished #Success                     22.0   45.0
# 43        #CozyNight #MovieTime                         18.0   35.0
# 44        #Art #GalleryExplore                          15.0   30.0
# 45         #BookRelease #FavoriteAuthor                 12.0   25.0
# 46        #VRMeetup #VirtualReality                     28.0   55.0
# 47        #Nature #Reflection                           15.0   30.0
# 48         #Cooking #SpecialDinner                      20.0   40.0
# 49         #Optimism #NewWeek                           15.0   30.0
# 50         #FitnessChallenge #NewBeginnings             22.0   45.0
# 51         #BikeRide #ScenicTrails                      18.0   35.0
# 52   #Injustice #Angry                                  20.0   40.0
# 53   #Fear #ThrillerMovie                               15.0   30.0
# 54   #Sadness #NaturalDisaster                          25.0   50.0
# 55   #Disgust #Environment                              18.0   35.0
# 56      #Happiness #Celebration                         30.0   60.0
# 57   #Joy #ComedyShow                                   22.0   45.0
# 58   #Love #SpreadLove                                  15.0   30.0
# 59   #Amusement #FunTimes                               18.0   35.0
#
#       Country  Year     Month  Day  Hour Day_of_week  \
# 0         USA  2023   January   15    12      Sunday
# 1      Canada  2023   January   15     8      Sunday
# 2         USA  2023   January   15    15      Sunday
# 3          UK  2023   January   15    18      Sunday
# 4   Australia  2023   January   15    19      Sunday
# 5       India  2023   January   16     9      Monday
# 6      Canada  2023   January   16    14      Monday
# 7         USA  2023   January   16    19      Monday
# 8         USA  2023   January   17     8     Tuesday
# 9   Australia  2023   January   17    12     Tuesday
# 10        USA  2023   January   17    15     Tuesday
# 11     Canada  2023   January   18    10   Wednesday
# 12         UK  2023   January   18    14   Wednesday
# 13        USA  2023   January   18    18   Wednesday
# 14      India  2023   January   19     9    Thursday
# 15        USA  2023   January   19    13    Thursday
# 16     Canada  2023   January   19    17    Thursday
# 17         UK  2023   January   20     0      Friday
# 18        USA  2023   January   20    11      Friday
# 19        USA  2023   January   20    15      Friday
# 20      India  2023   January   21     8    Saturday
# 21        USA  2023   January   21    13    Saturday
# 22        USA  2023   January   21    16    Saturday
# 23         UK  2023   January   22     9      Sunday
# 24     Canada  2023   January   22    14      Sunday
# 25         UK  2023   January   22    12      Sunday
# 26      India  2023   January   23    16      Monday
# 27  Australia  2023   January   23    19      Monday
# 28        USA  2023   January   24    11     Tuesday
# 29     Canada  2023   January   24    15     Tuesday
# 30         UK  2023   January   24    17     Tuesday
# 31      India  2023   January   25    18   Wednesday
# 32        USA  2023   January   25    13   Wednesday
# 33        USA  2023   January   26     9    Thursday
# 34     Canada  2023   January   26    14    Thursday
# 35         UK  2023   January   26    17    Thursday
# 36        USA  2023   January   27    20      Friday
# 37      India  2023   January   27    12      Friday
# 38     Canada  2023   January   27    16      Friday
# 39        USA  2023   January   28     9    Saturday
# 40        USA  2023   January   28    14    Saturday
# 41         UK  2023   January   28    19    Saturday
# 42      India  2023   January   29    17      Sunday
# 43     Canada  2023   January   29    20      Sunday
# 44        USA  2023   January   30    11      Monday
# 45         UK  2023   January   30    15      Monday
# 46      India  2023   January   30    18      Monday
# 47  Australia  2023   January   31    10     Tuesday
# 48        USA  2023   January   31    19     Tuesday
# 49     Canada  2023   January   31    16     Tuesday
# 50         UK  2023  February    1     8   Wednesday
# 51        USA  2023  February    1    13   Wednesday
# 52     Canada  2023  February   11     9    Saturday
# 53        USA  2023  February   11    21    Saturday
# 54      India  2023  February   12    14      Sunday
# 55         UK  2023  February   12    18      Sunday
# 56        USA  2023  February   13    10      Monday
# 57     Canada  2023  February   13    19      Monday
# 58  Australia  2023  February   14     8     Tuesday
# 59         UK  2023  February   14    14     Tuesday
#
#                                            Clean_Text  Sentiment_Score  \
# 0    enjoying a beautiful day at the park         ...           0.5574
# 1    traffic was terrible this morning            ...          -0.5719
# 2    just finished an amazing workout                           0.5574
# 3    excited about the upcoming weekend getaway   ...           0.5574
# 4    trying out a new recipe for dinner tonight   ...           0.0000
# 5    feeling grateful for the little things in lif...           0.5574
# 6    rainy days call for cozy blankets and hot coc...           0.5574
# 7    the new movie release is a mustwatch         ...           0.5574
# 8    political discussions heating up on the timel...          -0.5719
# 9    missing summer vibes and beach days          ...           0.0000
# 10   just published a new blog post check it out  ...           0.5574
# 11   feeling a bit under the weather today        ...          -0.5719
# 12   exploring the citys hidden gems              ...           0.5574
# 13    new year new fitness goals                                0.5574
# 14   technology is changing the way we live       ...           0.0000
# 15   reflecting on the past and looking ahead     ...           0.5574
# 16    just adopted a cute furry friend                          0.5574
# 17   latenight gaming session with friends        ...           0.5574
# 18   attending a virtual conference on ai         ...           0.0000
# 19   winter blues got me feeling low              ...          -0.5719
# 20   sipping coffee and enjoying a good book      ...           0.5574
# 21   exploring the world of virtual reality       ...           0.5574
# 22   productive day ticking off my todo list      ...           0.5574
# 23   just finished a challenging workout routine  ...           0.5574
# 24    celebrating a milestone at work                           0.5574
# 25   sunday brunch with friends                   ...           0.5574
# 26   learning a new language for personal growth  ...           0.5574
# 27   quiet evening with a good book               ...           0.5574
# 28   reflecting on the importance of mental health...           0.5574
# 29   new painting in progress                                   0.5574
# 30   weekend road trip to explore scenic views    ...           0.5574
# 31   enjoying a cup of tea and watching the sunset...           0.5574
# 32   coding a new project with enthusiasm         ...           0.5574
# 33   feeling inspired after attending a workshop  ...           0.5574
# 34   winter sports day at the local park          ...           0.5574
# 35   quality time with family this weekend        ...           0.5574
# 36   attending a live music concert tonight       ...           0.5574
# 37   practicing mindfulness with meditation       ...           0.5574
# 38   trying out a new dessert recipe              ...           0.5574
# 39   excited about the upcoming gaming tournament ...           0.5574
# 40   planning a garden makeover for spring        ...           0.5574
# 41     celebrating a friends birthday tonight                   0.5574
# 42   feeling accomplished after a productive day  ...           0.5574
# 43   a cozy evening with a good movie             ...           0.5574
# 44   exploring local art galleries this weekend   ...           0.5574
# 45   new book release from my favorite author     ...           0.5574
# 46   attending a virtual reality meetup           ...           0.5574
# 47   reflecting on the beauty of nature           ...           0.5574
# 48   cooking a special dinner for loved ones      ...           0.5574
# 49   feeling optimistic about the week ahead      ...           0.5574
# 50    starting a new fitness challenge tomorrow                 0.5574
# 51   sunday bike ride through scenic trails       ...           0.5574
# 52   cant believe the injustice happening in our s...          -0.5719
# 53   feeling a sense of fear after watching a thri...          -0.4939
# 54   heartbroken after hearing the news about a na...          -0.4404
# 55   the state of the worlds environment is just d...          -0.5994
# 56   pure happiness celebrating a loved ones achie...           0.5574
# 57   laughter is the best medicineenjoying a comed...           0.5859
# 58   sharing love and positive vibes with everyone...           0.6369
# 59   an amusing incident brightened up my day     ...           0.3612
#
#    Sentiment_Nature                                       Cleaned_Text  \
# 0          positive   enjoying a beautiful day at the park!        ...
# 1          negative   traffic was terrible this morning            ...
# 2          positive   just finished an amazing workout!            ...
# 3          positive   excited about the upcoming weekend getaway!  ...
# 4           neutral   trying out a new recipe for dinner tonight   ...
# 5          positive   feeling grateful for the little things in lif...
# 6          positive   rainy days call for cozy blankets and hot coc...
# 7          positive   the new movie release is a mustwatch!        ...
# 8          negative   political discussions heating up on the timel...
# 9           neutral   missing summer vibes and beach days          ...
# 10         positive   just published a new blog post check it out! ...
# 11         negative   feeling a bit under the weather today        ...
# 12         positive   exploring the citys hidden gems              ...
# 13         positive   new year new fitness goals!
# 14          neutral   technology is changing the way we live       ...
# 15         positive   reflecting on the past and looking ahead     ...
# 16         positive   just adopted a cute furry friend!
# 17         positive   latenight gaming session with friends        ...
# 18          neutral   attending a virtual conference on ai         ...
# 19         negative   winter blues got me feeling low              ...
# 20         positive   sipping coffee and enjoying a good book      ...
# 21         positive   exploring the world of virtual reality       ...
# 22         positive   productive day ticking off my todo list      ...
# 23         positive   just finished a challenging workout routine  ...
# 24         positive   celebrating a milestone at work!
# 25         positive   sunday brunch with friends                   ...
# 26         positive   learning a new language for personal growth  ...
# 27         positive   quiet evening with a good book               ...
# 28         positive   reflecting on the importance of mental health...
# 29         positive   new painting in progress!                    ...
# 30         positive   weekend road trip to explore scenic views    ...
# 31         positive   enjoying a cup of tea and watching the sunset...
# 32         positive   coding a new project with enthusiasm         ...
# 33         positive   feeling inspired after attending a workshop  ...
# 34         positive   winter sports day at the local park          ...
# 35         positive   quality time with family this weekend        ...
# 36         positive   attending a live music concert tonight       ...
# 37         positive   practicing mindfulness with meditation       ...
# 38         positive   trying out a new dessert recipe              ...
# 39         positive   excited about the upcoming gaming tournament ...
# 40         positive   planning a garden makeover for spring        ...
# 41         positive    celebrating a friends birthday tonight!
# 42         positive   feeling accomplished after a productive day  ...
# 43         positive   a cozy evening with a good movie             ...
# 44         positive   exploring local art galleries this weekend   ...
# 45         positive   new book release from my favorite author!    ...
# 46         positive   attending a virtual reality meetup           ...
# 47         positive   reflecting on the beauty of nature           ...
# 48         positive   cooking a special dinner for loved ones      ...
# 49         positive   feeling optimistic about the week ahead      ...
# 50         positive   starting a new fitness challenge tomorrow!
# 51         positive   sunday bike ride through scenic trails       ...
# 52         negative   cant believe the injustice happening in our s...
# 53         negative   feeling a sense of fear after watching a thri...
# 54         negative   heartbroken after hearing the news about a na...
# 55         negative   the state of the worlds environment is just d...
# 56         positive   pure happiness celebrating a loved ones achie...
# 57         positive   laughter is the best medicineenjoying a comed...
# 58         positive   sharing love and positive vibes with everyone...
# 59         positive   an amusing incident brightened up my day!    ...
#
#     Text_Sentiment_Score Text_Sentiment_Nature
# 0                 0.8221              positive
# 1                -0.4767              negative
# 2                 0.6239              positive
# 3                 0.4003              positive
# 4                 0.0000               neutral
# 5                 0.5423              positive
# 6                -0.0772              negative
# 7                 0.0000               neutral
# 8                 0.0000               neutral
# 9                -0.2960              negative
# 10                0.0000               neutral
# 11                0.1280              positive
# 12                0.0000               neutral
# 13                0.3382              positive
# 14                0.0000               neutral
# 15                0.0000               neutral
# 16                0.7574              positive
# 17                0.4767              positive
# 18                0.0000               neutral
# 19               -0.1531              negative
# 20                0.7430              positive
# 21                0.0000               neutral
# 22                0.0000               neutral
# 23                0.1531              positive
# 24                0.6114              positive
# 25                0.4767              positive
# 26                0.3818              positive
# 27                0.4404              positive
# 28                0.3612              positive
# 29                0.4753              positive
# 30                0.0000               neutral
# 31                0.5267              positive
# 32                0.4404              positive
# 33                0.5719              positive
# 34                0.0000               neutral
# 35                0.0000               neutral
# 36                0.0000               neutral
# 37                0.0000               neutral
# 38                0.0000               neutral
# 39                0.3400              positive
# 40                0.0000               neutral
# 41                0.7959              positive
# 42                0.5267              positive
# 43                0.4404              positive
# 44                0.0000               neutral
# 45                0.5093              positive
# 46                0.0000               neutral
# 47                0.5859              positive
# 48                0.7650              positive
# 49                0.4215              positive
# 50                0.4003              positive
# 51                0.0000               neutral
# 52                0.4585              positive
# 53               -0.3182              negative
# 54               -0.7845              negative
# 55               -0.5267              negative
# 56                0.9098              positive
# 57                0.8720              positive
# 58                0.8977              positive
# 59                0.7177              positive

# %%
# comparing thr rows having same sentiment nature
correct_label = df1[df1['Sentiment_Nature'] == df1['Text_Sentiment_Nature']].shape[0]

# %%
correct_label
# Out:
# 507

# %%
# calculating the pencentage of correct labels
total_rows = df1.shape[0]
correct_label = (correct_label / total_rows) * 100
correct_label
# Out:
# 71.20786516853933

# %% [markdown]
# # Based on sentimet nature score, 71.2% sentiment data are labeled correctly in nature(positive, negative, neutral).

# %%
# Time-Based Sentiment Trend Visualization
df1.set_index('Timestamp').resample('W')['Sentiment_Score'].mean().plot(figsize=(12,6), title='Weekly Average Sentiment')
plt.ylabel('Average Sentiment Score')
plt.xlabel('Date')
plt.title('Weekly Average Sentiment Trend')
plt.show()

# %% [markdown]
# ###  Platform-Based Sentiment Analysis

# %%
sns.boxplot(x='Platform', y='Sentiment_Score', data=df1)
plt.title('Sentiment Score Distribution by Platform')
plt.xticks(rotation=45)
plt.show()

# %%
## visualize the major sentiment composition in each category of the sentiment nature
df1['Sentiment_Nature'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(4,4), colormap='viridis')
plt.title('Sentiment Nature Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### Word Cloud or Keyword Extraction

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\chandan\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in c:\users\chandan\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (11.0.0)
# Requirement already satisfied: matplotlib in c:\users\chandan\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\chandan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\chandan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chandan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\chandan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\chandan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\chandan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chandan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\chandan\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud

# %%
df1.columns
# Out:
# Index(['Text', 'Sentiment', 'Timestamp', 'User', 'Platform', 'Hashtags',
#        'Retweets', 'Likes', 'Country', 'Year', 'Month', 'Day', 'Hour',
#        'Day_of_week', 'Clean_Text', 'Sentiment_Score', 'Sentiment_Nature',
#        'Cleaned_Text', 'Text_Sentiment_Score', 'Text_Sentiment_Nature'],
#       dtype='object')

# %% [markdown]
# ## Positive Sentiment Word Cloud Generation

# %%
positive_text = ' '.join(df1[df1['Sentiment_Nature'] == 'positive']['Clean_Text'])
WordCloud(width=800, height=400).generate(positive_text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>
